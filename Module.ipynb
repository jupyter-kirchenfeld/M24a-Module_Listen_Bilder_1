# %% [markdown]
# # Module
#
# Python ist modular aufgebaut. Das heisst, neben einem bestimmten Satz an schon vorhandenen Grundfunktionalitäten können **zusätzliche Funktionalitäten** mit der Hilfe von sogenannten **Modulen** hinzugefügt werden. Diese Module kann man selbst erstellen oder von anderen Entwickler:innen übernehmen. Module sind nichts anderes als Dateien mit Python Code.
#
# Der modulare Aufbau hilft, Code übersichtlich zu organisieren. Die Idee von Modulen ist die **Wiederverwertbarkeit von Code**. Genau so wie eine Funktion dazu dient, einen bestimmten Code innerhalb eines Programms mehrfach auszuführen, dienen Module dazu, Programmcode über mehrere Projekte hinweg wiederverwenden zu können.
#
# ## Ein bestehendens Modul verwenden
#
# Es existieren sogenannte *[Built-in Modules](https://docs.python.org/3/py-modindex.html)*, um diese zu verwenden müssen sie importiert werden. Dies geschieht mit dem Schlüsselwort `import`:

# %%
import random

# %% [markdown]
# Danach stehen uns alle Funktionen des [random Modul](https://docs.python.org/3/library/random.html#functions-for-integers) zur Verfügung
#
# ### Aufgabe
#
# Suchen Sie auf der vorherrigen Seite nach einer Funktion namens `randint(a, b)` und überlegen Sie ein Beispiel indem diese Funktion verwendet werden könnte.

# %% [markdown]
# Schreiben Sie Ihre Antwort in diese Zelle

# %% [markdown]
# Ein weiteres sehr praktisches `Built-in` Modul ist das [math Modul](https://docs.python.org/3/library/math.html#module-math). Wie Sie auf der verlinkten Seite sehen, beinhaltet dieses Modul viele praktische Funktionen, welche Python zu einem perfekten Taschenrechner Ersatz machen.
#
# ### Aufgabe
#
# Kombinieren Sie die Funktionen [randrange](https://docs.python.org/3/library/random.html#random.randrange) und [isqrt](https://docs.python.org/3/library/math.html#math.isqrt) um von einer zufälligen Zahl zwischen 0 - 99 die Quadratwurzel zu berechnen.

# %%
import random
import math
### Schreiben Sie Ihren Code hier

# %% [markdown]
# ### Zusatzaufgabe
#
# Erstellen Sie eine Variante des vorherrigen Beispiel welches für Komma-Zahlen zwischen 0.0 bis 99.0 die Quadratwurzel berechnet
#
# **Tipp:** Suchen Sie unter [Real-valued distributions](https://docs.python.org/3/library/random.html#real-valued-distributions)

# %%
import random
import math
### Schreiben Sie Ihren Code hier

# %% [markdown]
# ## Listen und Random
#
# Nun wollen wir unser Wissen über Listen und For-Schleifen mit dem `random` Modul verknüpfen. Die folgende Zelle beinhaltet den Code um eine Liste mit 5 zufälligen Zahlen zwischen 0 bis 10 zu erstellen:

# %%
import random
meine_liste = []
for x in range(5):
    zahl = random.randint(0, 10)
    meine_liste.append(zahl)
meine_liste

# %% [markdown]
# ### Aufgabe
#
# - Kopieren und verändern Sie den Code damit die Liste 10 zufällige Zahlen enthält.
# - Gehen Sie auf erneut auf die [random Modul](https://docs.python.org/3/library/random.html#functions-for-sequences) Seite und erweitern Sie den Code, so dass am Schluss ein **zufälliges** Element aus der Liste zurück gegeben wird

# %%
### Schreiben Sie Ihren Code hier

# %% [markdown]
# ### Zusatzaufgabe
#
# Lesen Sie auf der [random Modul](https://docs.python.org/3/library/random.html#bookkeeping-functions) was die `seed` Funktion macht und beschreiben Sie in eigenen Worten warum und in welchem Kontext dies relevant sein könnte.

# %% [markdown]
# Schreiben Sie Ihre Antwort in diese Zelle
